# %%
import pyvista
from pyvista import examples
import numpy as np

# %% [raw]
# cas 1 : polydata

# %%
poly = pyvista.Polygon(n_sides=6)

# %%
poly.plot(line_width=1, show_edges=True)
# Out:
# /home/gfa/.local/lib/python3.6/site-packages/pyvista/jupyter/notebook.py:60: UserWarning: Failed to use notebook backend:
#
# Please install `ipyvtklink` to use this feature: https://github.com/Kitware/ipyvtklink
#
# Falling back to a static output.
#   warnings.warn(f'Failed to use notebook backend: \n\n{e}\n\n'
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F120A5A6278>

# %%
volume = poly.extrude((1, 2, 2), capping=True)

# %%
volume.plot(line_width=1, show_edges=True)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F1208335A20>

# %% [raw]
# cas 2 : untsruturedgrid (need to convert in polydata (with geopfilter?)

# %%
x = np.arange(-10, 10, 0.25)
y = np.arange(-10, 10, 0.25)
x, y = np.meshgrid(x, y)
r = np.sqrt(x ** 2 + y ** 2)
z = np.sin(r)

# %%
grid = pyvista.StructuredGrid(x, y, z)
grid.plot()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F12082C40B8>

# %%
volumebis = grid.extrude((1, 2, 2), capping=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-ed8d0ef4f628> in <module>
# ----> 1 volumebis = grid.extrude((1, 2, 2), capping=True)
#
# ~/.local/lib/python3.6/site-packages/pyvista/core/dataset.py in __getattr__(self, item)
#     100     def __getattr__(self, item) -> Any:
#     101         """Get attribute from base class if not found."""
# --> 102         return super().__getattribute__(item)
#     103
#     104     @property
#
# AttributeError: 'StructuredGrid' object has no attribute 'extrude'

# %%
volumebis.plot()
