# %% [markdown]
# # First trial at displaying a coal seam created with gdf_to_ug
#
# Only the contours are reconstructed, not the surfaces not to say the volumes...

# %%
import geopandas as gpd
from geometron.geom_to_vtk import gdf_to_ug
import pyvista as pv

# %%
gdf = gpd.read_file('../../../../data/example.gpkg', layer = 'Parties exploitées - Caillette')

# %%
gdf.head()
# Out:
#    Année                                           geometry
# 0   1941  POLYGON Z ((154613.672 123991.170 -663.000, 15...
# 1   1942  POLYGON Z ((154816.546 123955.316 -671.100, 15...
# 2   1939  POLYGON Z ((154912.246 123824.192 -686.800, 15...
# 3   1942  POLYGON Z ((154868.618 123744.141 -698.900, 15...
# 4   1938  POLYGON Z ((154949.664 123925.004 -679.300, 15...

# %%
ug = gdf_to_ug(gdf)
ug
# Out:
# UnstructuredGrid (0x7f1b3d171dc0)
#   N Cells:	32
#   N Points:	558
#   X Bounds:	1.545e+05, 1.563e+05
#   Y Bounds:	1.235e+05, 1.247e+05
#   Z Bounds:	-7.206e+02, 0.000e+00
#   N Arrays:	1

# %% [markdown]
# ## Interactive representation

# %%
dargs = dict(scalars='Elevation', cmap='rainbow', show_edges=True, window_size=(1024,480))

ug.plot(jupyter_backend='panel', color='w', style='surface', interpolate_before_map=True,
           scalar_bar_args={'title': 'Elevation'},
           **dargs)
# Out:
# <div id='1004'>
#
#
#
#
#
#   <div class="bk-root" id="684701e5-6985-41a9-992c-87f8842c9c64" data-root-id="1004"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   function embed_document(root) {
#     var docs_json = {"f1693d46-8370-413c-b9ac-5009a55665f2":{"defs":[{"extends":null,"module":null,"name":"ReactiveHTML1","overrides":[],"properties":[]},{"extends":null,"module":null,"name":"FlexBox1","overrides":[],"properties":[{"default":"flex-start","kind":null,"name":"align_content"},{"default":"flex-start","kind":null,"name":"align_items"},{"default":"row","kind":null,"name":"flex_direction"},{"default":"wrap","kind":null,"name":"flex_wrap"},{"default":"flex-start","kind":null,"name":"justify_content"}]},{"extends":null,"module":null,"name":"TemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]},{"extends":null,"module":null,"name":"MaterialTemplateActions1","overrides":[],"properties":[{"default":0,"kind":null,"name":"open_modal"},{"default":0,"kind":null,"name":"close_modal"}]}],"roots":{"references":[{"attributes":{"client_comm_id":"397f029ed05042988d43c273379ad7db","comm_id":"7e7052b31f1a4d108471923dd27589b2","plot_id":"1004"},"id":"1005","type":"panel.models.comm_manager.CommManager"},{"attributes":{"arrays":{"7774555f542029438b32c490b5e8070b":"...","d5a9c30dde309ac6946b427b4a8f3d82":"...","fc4eb5d77851bde59d84fc7818e93d80":"...","ffbec26a6bf0af682263ba7c6f4b09ca":"..."},"axes":{"id":"1003"},"color_mappers":[{"id":"1002"}],"height":480,"margin":[5,5,5,5],"orientation_widget":true,"scene":{"calls":[["addRenderer",["instance:${ad483b84-0dd4-4ebe-aed3-3d9e890145fd0000000003b38070}"]],["addRenderer",["instance:${ad483b84-0dd4-4ebe-aed3-3d9e890145fd0000000003b1bd70}"]],["addRenderer",["instance:${ad483b84-0dd4-4ebe-aed3-3d9e890145fd0000000003f01560}"]]],"dependencies":[{"calls":[["setActiveCamera",["instance:${0000000003b3d310}"]],["addViewProp",["instance:${ad483b84-0dd4-4ebe-aed3-3d9e890145fd0000000003f0c390}"]]],"dependencies":[{"id":"0000000003b3d310","parent":"ad483b84-0dd4-4ebe-aed3-3d9e890145fd0000000003b38070","properties":{"clippingRange":[2205.67884688594,7090.021215954896],"focalPoint":[155392.05136358127,124128.19719296414,-360.3],"position":[157911.2538825768,126647.39971195969,2158.902518995545],"viewUp":[0.0,0.0,1.0]},"type":"vtkOpenGLCamera"},{"calls":[["setMapper",["instance:${ad483b84-0dd4-4ebe-aed3-3d9e890145fd0000000003e97480}"]],["setProperty",["instance:${ad483b84-0dd4-4ebe-aed3-3d9e890145fd0000000003f0cce0}"]]],"dependencies":[{"calls":[["setInputData",["instance:${ad483b84-0dd4-4ebe-aed3-3d9e890145fd0000000003e97480-dataset-0}",0]],["setLookupTable",["instance:${ad483b84-0dd4-4ebe-aed3-3d9e890145fd0000000003f0bc30}"]]],"dependencies":[{"id":"ad483b84-0dd4-4ebe-aed3-3d9e890145fd0000000003e97480-dataset-0","parent":"ad483b84-0dd4-4ebe-aed3-3d9e890145fd0000000003e97480","properties":{"fields":[{"dataType":"Float64Array","hash":"fc4eb5d77851bde59d84fc7818e93d80","location":"pointData","name":"Elevation","numberOfComponents":1,"ranges":[{"component":null,"max":0.0,"min":-720.6}],"registration":"setScalars","size":558,"vtkClass":"vtkDataArray"}],"lines":{"dataType":"Uint32Array","hash":"d5a9c30dde309ac6946b427b4a8f3d82","name":null,"numberOfComponents":1,"ranges":[{"component":null,"max":557.0,"min":0.0}],"size":590,"vtkClass":"vtkCellArray"},"points":{"dataType":"Float64Array","hash":"7774555f542029438b32c490b5e8070b","name":"Points","numberOfComponents":3,"ranges":[{"component":null,"max":156291.21217554505,"min":154492.8905516175},{"component":null,"max":124708.77841790004,"min":123547.61596802824},{"component":null,"max":0.0,"min":-720.6},{"component":null,"max":199933.9063902433,"min":198082.50032973822}],"size":1674,"vtkClass":"vtkPoints"}},"type":"vtkPolyData"},{"arrays":[{"dataType":"Uint8Array","hash":"ffbec26a6bf0af682263ba7c6f4b09ca","name":null,"numberOfComponents":4,"ranges":[{"component":null,"max":255.0,"min":0.0},{"component":null,"max":254.0,"min":0.0},{"component":null,"max":255.0,"min":0.0},{"component":null,"max":255.0,"min":255.0},{"component":null,"max":422.98699743609143,"min":360.6244584051392 ...

# %% [markdown]
# ## Static representation for thumbnail

# %%
dargs = dict(scalars='Elevation', cmap='rainbow', show_edges=True, window_size=(1024,480))

ug.plot(jupyter_backend='static', color='w', style='surface', interpolate_before_map=True,
        scalar_bar_args={'title': 'Elevation'}, **dargs)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x480 at 0x7F1B35824D90>
